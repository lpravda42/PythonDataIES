# %%
for i in range(9):
    print(f"{i} is the value")
# Out:
# 0 is the value
# 1 is the value
# 2 is the value
# 3 is the value
# 4 is the value
# 5 is the value
# 6 is the value
# 7 is the value
# 8 is the value

# %%
l = [3, 4, 5]

[e**2 for e in l]

t = 1, 2

(e+2 for e in t)

#also for dict ??????????
# Out:
# <generator object <genexpr> at 0x000002316647F850>

# %%
import numpy as np

# %%
import pandas as pd
import requests

r2 = requests.get("https://www.google.com/")
#print(r2.text)

r = requests.get("https://www.sreality.cz/api/cs/v2/estates?category_main_cb=2&category_type_cb=1&per_page=20&tms=1678732849172").json()
print(r)
"""
print(r.keys())
pd.json_normalize(r["_embedded"])
pd.json_normalize(r["_embedded"]["estates"]).keys()
pd.json_normalize(r["_embedded"]["estates"]).head()
"""
# Out:
# {'meta_description': '17742 realit v nabídce prodej domů a nemovitostí. Vyberte si novou nemovitost na sreality.cz s hledáním na mapě a velkými náhledy fotografií nabízených domů a nemovitostí.', 'result_size': 17742, '_embedded': {'estates': [{'labelsReleased': [[], []], 'has_panorama': 0, 'labels': [], 'is_auction': False, 'labelsAll': [['not_furnished'], ['playground', 'small_shop', 'tavern', 'movies', 'kindergarten', 'restaurant', 'post_office', 'sports', 'bus_public_transport', 'school']], 'seo': {'category_main_cb': 2, 'category_sub_cb': 44, 'category_type_cb': 1, 'locality': 'peruc-cernochov-'}, 'exclusively_at_rk': 1, 'category': 2, 'has_floor_plan': 1, '_embedded': {'favourite': {'is_favourite': False, '_links': {'self': {'profile': '/favourite/doc', 'href': '/cs/v2/favourite/260678732', 'title': 'Oblibene inzeraty'}}}, 'note': {'note': '', '_links': {'self': {'profile': '/note/doc', 'href': '/cs/v2/note/260678732', 'title': 'Poznamky inzeratu'}}, 'has_note': False}}, 'paid_
# ...
