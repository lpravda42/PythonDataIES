# %%
import pandas as pd
import requests

r = requests.get("https://www.googleapis.com/books/v1/volumes?q=python+programming&maxResults=30").json()

# %%
df = pd.DataFrame([r["items"][i]["volumeInfo"] for i in range(len(r["items"]))])
df
# Out:
#                                                 title  \
# 0                     Python Programming Fundamentals
# 1                           Expert Python Programming
# 2                                  Python Programming
# 3       Beginning Programming with Python For Dummies
# 4                             Programming in Python 3
# 5                        Basics of Python Programming
# 6                           Expert Python Programming
# 7                            Learn Python Programming
# 8                       Python Programming in Context
# 9                      Python Programming for Biology
# 10                        Python Programming On Win32
# 11                 Introduction to Python Programming
# 12                            Teach Your Kids to Code
# 13                   Python Programming For Beginners
# 14                                   Black Hat Python
# 15                   Python Programming For Beginners
# ...
