# %%
import requests
import pandas as pd
import time

# %% [markdown]
# # Seminar - APIs and real-life coding

# %% [markdown]
# ## Task 1: Requesting API
# ### 1a. Create a function requesting data from sreality
#
# ```python
# base_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb=1&category_type_cb=1&locality_region_id=10&per_page60&page={}'.format(i)
#
# r = requests.get(base_url)
# d = r.json()
# ```
#
# * function should parametrize:
#     * `category_main_cb` - `{'flat':1, 'house':2, 'land':3 }`
#     * `category_type_cb` - `{'sell':1,'rent':2}`
#     * `locality_region_id` - `{'Praha':10,'Brno':14}`
#     * `page` parameter
# * use string inputs for `category_main_cb` and `category_type_cb`
# * test the validity of inputs
# * include try/except clause to handle errors
# * function should return JSON data in python types
# * do not forget to sleep each request at least 0.5s

# %%
def getting_sreality(category_main_cb, category_type_cb, locality_region_id, page):
    try:
        if requests.get('https://www.sreality.cz/api/cs/v2/estates?category_main_cb={}&category_type_cb={}&locality_region_id={}&per_page60&page={}'.format(category_main_cb, category_type_cb, locality_region_id, page)).ok:
            return requests.get('https://www.sreality.cz/api/cs/v2/estates?category_main_cb={}&category_type_cb={}&locality_region_id={}&per_page60&page={}'.format(category_main_cb, category_type_cb, locality_region_id, page)).json()
    except:
        return "the request was unsuccessful"

main_dict = {'flat':1, 'house':2, 'land':3 }
type_dict = {'sell':1,'rent':2}
locality_dict = {'Praha':10,'Brno':14}

def getting_value(inp, dict):
    if inp in dict.keys():
        return dict[inp]
    else:
        try:
            getting_value(input("wrong input, try again: "), dict)
        except:
            return "you have exceeded the number of tries"
            

category_main_cb = getting_value(input("category_main_cb input: "), main_dict)
category_type_cb = getting_value(input("category_type_cb input: "), type_dict)
locality_region_id = getting_value(input("category_main_cb_input: "), locality_dict)
#page = int(input("page input: "))

# %% [markdown]
# ### 1b. Create a function converting sreality json data into pandas dataframe

# %%
def sreality_to_pd(json_data):
    try:
        return pd.read_json(json_data)
    except:
        return json_data

# %% [markdown]
# ### 1c. link function `1b` into function `1a`

# %%
sreality_to_pd(getting_sreality(category_main_cb, category_type_cb, locality_region_id, page))
# Out:
# {'meta_description': '5905 realit v nabídce prodej bytů Praha. Vyberte si novou nemovitost na sreality.cz s hledáním na mapě a velkými náhledy fotografií nabízených bytů.',
#  'result_size': 5905,
#  '_embedded': {'estates': [{'labelsReleased': [['new_building',
#       'not_furnished'],
#      []],
#     'has_panorama': 0,
#     'labels': ['Novostavba', 'Nevybavený'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'cellar',
#       'elevator',
#       'parking_lots',
#       'garage',
#       'not_furnished'],
#      ['playground',
#       'small_shop',
#       'candy_shop',
#       'tavern',
#       'theater',
#       'vet',
#       'movies',
#       'sightseeing',
#       'tram',
#       'train',
#       'post_office',
#       'kindergarten',
#       'drugstore',
#       'bus_public_transport',
#       'school',
#       'metro',
#       'shop',
#       'medic',
#       'restaurant',
#       'atm',
#       'sports']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-zizkov-krasova'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/606610508',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/606610508',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'CTR-Viktoria-Center-Praha-Zizkov',
#       'id': 27177,
#       'name': 'CTR Viktoria Center',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_F_L/KFwI3w.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 3 - Žižkov',
#     'has_video': False,
#     'advert_images_count': 15,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 606610508,
#     'attractive_offer': 0,
#     'price': 15722000,
#     'price_czk': {'value_raw': 15722000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Ky/vJvL0G.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Ky/vJvL0G.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/0?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/606610508?region_tip=2444733'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Ky/vJvL0G.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/kSYnCe.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jz/TQfW1V.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/nOWBiYe.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jz/hTwW1W.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/kz5BiYf.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Ky/vJvL0G.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 104\xa0m²',
#     'region_tip': 2444733,
#     'gps': {'lat': 50.0703224108948, 'lon': 14.460248589105197},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'cellar', 'partly_furnished'],
#      ['playground',
#       'natural_attraction',
#       'small_shop',
#       'vet',
#       'candy_shop',
#       'tavern',
#       'theater',
#       'movies',
#       'sightseeing',
#       'shop',
#       'post_office',
#       'restaurant',
#       'school',
#       'tram',
#       'train',
#       'metro',
#       'kindergarten',
#       'atm',
#       'sports',
#       'medic',
#       'drugstore',
#       'bus_public_transport']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-vinohrady-borivojova'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3751355468',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3751355468',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Grygar-reality-Praha-Vinohrady',
#       'id': 34012,
#       'name': 'Grygar reality',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gS_l/NIOZoC.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 3 - Vinohrady',
#     'has_video': False,
#     'advert_images_count': 29,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3751355468,
#     'attractive_offer': 0,
#     'price': 13601000,
#     'price_czk': {'value_raw': 13601000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kz/q2BFbE.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kz/q2BFbE.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/1?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3751355468'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kz/q2BFbE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jc/QslFTE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jh/l4OFTA.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L8/eoTFbE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Ji/EokFSg.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jc/jIzFTH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kz/q2BFbE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 119\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.06562641089481, 'lon': 14.468499589105196},
#     'has_matterport_url': False},
#    {'labelsReleased': [['new_building', 'terrace'], []],
#     'has_panorama': 0,
#     'labels': ['Novostavba', 'Terasa'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'terrace',
#       'cellar',
#       'elevator',
#       'garage'],
#      ['train',
#       'bus_public_transport',
#       'tram',
#       'metro',
#       'school',
#       'atm',
#       'restaurant',
#       'kindergarten',
#       'sports',
#       'small_shop',
#       'candy_shop',
#       'drugstore',
#       'theater',
#       'medic',
#       'movies',
#       'playground',
#       'vet',
#       'post_office',
#       'tavern',
#       'shop',
#       'sightseeing']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-vinohrady-perucka'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/924071500',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/924071500',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'PSN-s-r-o-Praha-Zizkov',
#       'id': 1160,
#       'name': 'PSN s.r.o.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_F_G/sFFSXu.jpeg?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 2 - Vinohrady',
#     'has_video': False,
#     'advert_images_count': 10,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 924071500,
#     'attractive_offer': 0,
#     'price': 12113000,
#     'price_czk': {'value_raw': 12113000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LX/qZGBOdu.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LX/qZGBOdu.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/2?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/924071500'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LX/qZGBOdu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jy/jJuBTYa.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jy/PDrBTYb.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jc/JVbYdg.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ks/aiABNkY.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/zFkYn8.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LX/qZGBOdu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 56\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.0546134108948, 'lon': 14.454398589105196},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction'], []],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'panel',
#       'elevator',
#       'parking_lots',
#       'garage'],
#      ['playground',
#       'sports',
#       'bus_public_transport',
#       'tram',
#       'restaurant',
#       'atm',
#       'small_shop',
#       'medic',
#       'kindergarten',
#       'candy_shop',
#       'drugstore',
#       'tavern',
#       'vet',
#       'school',
#       'theater',
#       'metro',
#       'post_office',
#       'shop',
#       'movies',
#       'train',
#       'natural_attraction']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 2,
#      'category_type_cb': 1,
#      'locality': 'praha-chodov-ceneticka'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/167035980',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/167035980',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'PSN-s-r-o-Praha-Zizkov',
#       'id': 1160,
#       'name': 'PSN s.r.o.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_F_G/sFFSXu.jpeg?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 4 - Chodov',
#     'has_video': False,
#     'advert_images_count': 18,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 167035980,
#     'attractive_offer': 0,
#     'price': 5274000,
#     'price_czk': {'value_raw': 5274000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/RUNYRC.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/RUNYRC.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/3?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/167035980'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/RUNYRC.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KW/Ss4rSs.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/6FoYnu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jy/MDgBTYU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jy/Nz6BTYV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ks/oJkBNkM.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/RUNYRC.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 1+kk 32\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.028841410894806, 'lon': 14.512607589105196},
#     'has_matterport_url': False},
#    {'labelsReleased': [['loggia', 'not_furnished'], ['shop']],
#     'has_panorama': 0,
#     'labels': ['Lodžie', 'Nevybavený', 'Obchod 6 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'loggia',
#       'panel',
#       'cellar',
#       'elevator',
#       'not_furnished'],
#      ['playground',
#       'small_shop',
#       'candy_shop',
#       'tavern',
#       'vet',
#       'theater',
#       'movies',
#       'kindergarten',
#       'atm',
#       'metro',
#       'post_office',
#       'school',
#       'restaurant',
#       'bus_public_transport',
#       'sports',
#       'train',
#       'drugstore',
#       'shop',
#       'tram',
#       'medic']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 5,
#      'category_type_cb': 1,
#      'locality': 'praha-branik-nad-lesnim-divadlem'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3505002316',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3505002316',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Hot-Real-Estate-Praha-Vinohrady',
#       'id': 5992,
#       'name': 'Hot Real Estate',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QO_h/JjkFCH.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 4 - Braník',
#     'has_video': False,
#     'advert_images_count': 20,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3505002316,
#     'attractive_offer': 0,
#     'price': 7405000,
#     'price_czk': {'value_raw': 7405000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_p/zslME1.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_p/zslME1.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/4?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3505002316'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_p/zslME1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jb/sRBTk0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_q/dEVMkd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_q/i7JMm0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KS/1JeTgl.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_q/aZKMkQ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_p/zslME1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+1\xa087\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.01195741089481, 'lon': 14.451540589105196},
#     'has_matterport_url': False},
#    {'labelsReleased': [['not_furnished'], ['metro', 'medic']],
#     'has_panorama': 0,
#     'labels': ['Nevybavený', 'Metro 4 min. pěšky', 'Lékař 6 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'panel', 'cellar', 'elevator', 'not_furnished'],
#      ['playground',
#       'tavern',
#       'small_shop',
#       'candy_shop',
#       'vet',
#       'natural_attraction',
#       'theater',
#       'movies',
#       'sightseeing',
#       'sports',
#       'post_office',
#       'metro',
#       'school',
#       'train',
#       'medic',
#       'kindergarten',
#       'bus_public_transport',
#       'tram',
#       'shop',
#       'restaurant',
#       'atm',
#       'drugstore']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-stodulky-nuslova'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2626827340',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2626827340',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Stodůlky',
#     'has_video': False,
#     'advert_images_count': 9,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2626827340,
#     'attractive_offer': 0,
#     'price': 5494000,
#     'price_czk': {'value_raw': 5494000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/BZeBA42.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/BZeBA42.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/5?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2626827340'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/BZeBA42.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KW/NezBTcH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ks/gJ0Bz6p.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ks/hyTBz6q.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/GfDBAjW.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/2bOaCc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/BZeBA42.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 61\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.039007410894804, 'lon': 14.363135589105196},
#     'has_matterport_url': False},
#    {'labelsReleased': [['new_building'], ['shop']],
#     'has_panorama': 0,
#     'labels': ['Novostavba', 'Obchod 318 metrů pěšky'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'cellar',
#       'elevator',
#       'parking_lots'],
#      ['playground',
#       'sports',
#       'restaurant',
#       'bus_public_transport',
#       'drugstore',
#       'kindergarten',
#       'shop',
#       'atm',
#       'candy_shop',
#       'small_shop',
#       'tavern',
#       'theater',
#       'vet',
#       'tram',
#       'school',
#       'post_office',
#       'metro',
#       'medic',
#       'movies',
#       'train',
#       'natural_attraction']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-horni-mecholupy-modenska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3535545420',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3535545420',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 10 - Horní Měcholupy',
#     'has_video': False,
#     'advert_images_count': 13,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3535545420,
#     'attractive_offer': 0,
#     'price': 9191000,
#     'price_czk': {'value_raw': 9191000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jc/qkeHC7.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jc/qkeHC7.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/6?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3535545420'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jc/qkeHC7.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J0/hB0HMN.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Ji/F7yHCW.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J0/WOkHMM.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L8/M5kHNC.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KX/lLgHKJ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jc/qkeHC7.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': True,
#     'name': 'Prodej bytu 2+kk 64\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.027586410894806, 'lon': 14.581976589105196},
#     'has_matterport_url': False},
#    {'labelsReleased': [['collective'], []],
#     'has_panorama': 0,
#     'labels': ['Družstevní'],
#     'is_auction': False,
#     'labelsAll': [['collective', 'panel', 'cellar'],
#      ['playground',
#       'small_shop',
#       'vet',
#       'tavern',
#       'movies',
#       'candy_shop',
#       'theater',
#       'medic',
#       'drugstore',
#       'sports',
#       'metro',
#       'atm',
#       'bus_public_transport',
#       'shop',
#       'school',
#       'restaurant',
#       'tram',
#       'post_office',
#       'kindergarten',
#       'train']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-vinor-ceperska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/229979212',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/229979212',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': '1JMREALITY-Praha-Vysocany',
#       'id': 1511,
#       'name': '1JMREALITY',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_G_C/TBlB9JS.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 9 - Vinoř',
#     'has_video': False,
#     'advert_images_count': 25,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 229979212,
#     'attractive_offer': 0,
#     'price': 5193000,
#     'price_czk': {'value_raw': 5193000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_La/blTHDs.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_La/blTHDs.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/7?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/229979212'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_La/blTHDs.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_La/qjKHDt.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jc/YAHG7B.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L8/k3RHHV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jh/QXEG91.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jz/gYCG8S.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_La/blTHDs.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 59\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.128698410894806, 'lon': 14.590446589105197},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['metro', 'shop']],
#     'has_panorama': 0,
#     'labels': ['Metro 2 min. pěšky', 'Obchod 4 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'cellar', 'elevator', 'garage'],
#      ['playground',
#       'natural_attraction',
#       'vet',
#       'candy_shop',
#       'small_shop',
#       'tavern',
#       'theater',
#       'movies',
#       'bus_public_transport',
#       'post_office',
#       'school',
#       'kindergarten',
#       'shop',
#       'sports',
#       'atm',
#       'restaurant',
#       'drugstore',
#       'medic',
#       'train',
#       'tram',
#       'metro']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-vysocany-bratri-dohalskych'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/4139263052',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/4139263052',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': '1JMREALITY-Praha-Vysocany',
#       'id': 1511,
#       'name': '1JMREALITY',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_G_C/TBlB9JS.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 9 - Vysočany',
#     'has_video': False,
#     'advert_images_count': 23,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 4139263052,
#     'attractive_offer': 0,
#     'price': 9878000,
#     'price_czk': {'value_raw': 9878000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kz/u6pHIL.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kz/u6pHIL.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/8?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/4139263052'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kz/u6pHIL.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L8/wHXHHT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kz/x3KHIM.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kv/wL1HBj.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kv/TAmHBk.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_La/w9AHDr.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kz/u6pHIL.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 82\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.097074410894805, 'lon': 14.513325589105197},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'cellar', 'elevator'],
#      ['playground',
#       'small_shop',
#       'candy_shop',
#       'tavern',
#       'theater',
#       'vet',
#       'movies',
#       'sightseeing',
#       'restaurant',
#       'train',
#       'post_office',
#       'tram',
#       'atm',
#       'bus_public_transport',
#       'shop',
#       'drugstore',
#       'school',
#       'kindergarten',
#       'sports',
#       'medic',
#       'metro']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-zizkov-kubelikova'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3233555532',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3233555532',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 3 - Žižkov',
#     'has_video': True,
#     'advert_images_count': 13,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3233555532,
#     'attractive_offer': 0,
#     'price': 7817000,
#     'price_czk': {'value_raw': 7817000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J0/Wr2HGL.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J0/Wr2HGL.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/9?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3233555532'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J0/Wr2HGL.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jz/hyoG8H.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kv/N3oHBX.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jz/oqPG8I.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KX/yR1HEd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kz/ptMHIC.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J0/Wr2HGL.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 56\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.068582410894805, 'lon': 14.466313589105196},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction', 'terrace'],
#      ['metro', 'medic']],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci',
#      'Terasa',
#      'Metro 1 min. pěšky',
#      'Lékař 3 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'terrace',
#       'panel',
#       'partly_furnished'],
#      ['playground',
#       'theater',
#       'small_shop',
#       'candy_shop',
#       'vet',
#       'tavern',
#       'movies',
#       'sightseeing',
#       'medic',
#       'tram',
#       'shop',
#       'atm',
#       'restaurant',
#       'train',
#       'kindergarten',
#       'metro',
#       'sports',
#       'school',
#       'post_office',
#       'drugstore',
#       'bus_public_transport']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-veleslavin-veleslavinska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2981897292',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2981897292',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 6 - Veleslavín',
#     'has_video': False,
#     'advert_images_count': 5,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2981897292,
#     'attractive_offer': 0,
#     'price': 10267000,
#     'price_czk': {'value_raw': 10267000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kv/Rr0HBd.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kv/Rr0HBd.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/10?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2981897292'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kv/Rr0HBd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jh/iphG9t.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jh/FFYG9u.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jz/K8PG8M.jpeg?fl=rot,270,0|res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jh/oiiG9v.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kv/Rr0HBd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': True,
#     'name': 'Prodej bytu 2+kk 72\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.08111041089481, 'lon': 14.361969589105197},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['metro', 'shop']],
#     'has_panorama': 0,
#     'labels': ['Metro 2 min. pěšky', 'Obchod 3 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'balcony', 'brick'],
#      ['candy_shop',
#       'vet',
#       'tavern',
#       'small_shop',
#       'theater',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'sightseeing',
#       'restaurant',
#       'drugstore',
#       'sports',
#       'post_office',
#       'shop',
#       'train',
#       'medic',
#       'tram',
#       'bus_public_transport',
#       'kindergarten',
#       'metro',
#       'school',
#       'atm']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-vinohrady-caslavska'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1991259212',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1991259212',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Real-Agency-360-Praha-Chodov',
#       'id': 6218,
#       'name': 'Real Agency 360',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_E_G/sylUEk.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 3 - Vinohrady',
#     'has_video': True,
#     'advert_images_count': 19,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1991259212,
#     'attractive_offer': 0,
#     'price': 12708000,
#     'price_czk': {'value_raw': 12708000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/FGZLYO.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/FGZLYO.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/11?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1991259212'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/FGZLYO.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/ToXB0IT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/fFVfwX.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/aQqBGP0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/OrfB0IU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/J3vB0IV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/FGZLYO.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 94\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.063474410894806, 'lon': 14.473376589105197},
#     'has_matterport_url': True},
#    {'labelsReleased': [['new_building'], []],
#     'has_panorama': 0,
#     'labels': ['Novostavba'],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'personal', 'elevator', 'garage'],
#      ['playground',
#       'small_shop',
#       'tavern',
#       'candy_shop',
#       'movies',
#       'theater',
#       'vet',
#       'natural_attraction',
#       'kindergarten',
#       'drugstore',
#       'shop',
#       'school',
#       'restaurant',
#       'train',
#       'bus_public_transport',
#       'metro',
#       'post_office',
#       'atm',
#       'sports',
#       'tram',
#       'medic']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-hlubocepy-dostalove'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2786600012',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2786600012',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Real-Agency-360-Praha-Chodov',
#       'id': 6218,
#       'name': 'Real Agency 360',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_E_G/sylUEk.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Hlubočepy',
#     'has_video': True,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2786600012,
#     'attractive_offer': 0,
#     'price': 14150000,
#     'price_czk': {'value_raw': 14150000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/8QTBHuk.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/8QTBHuk.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/12?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2786600012'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/8QTBHuk.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/7Y0BsHR.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/mySBHul.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Ky/ddVV32.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/VuyBHuo.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/wDYBsHS.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/8QTBHuk.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 89\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.0182244108948, 'lon': 14.394112589105196},
#     'has_matterport_url': True},
#    {'labelsReleased': [['new_building', 'loggia', 'terrace'], []],
#     'has_panorama': 0,
#     'labels': ['Novostavba', 'Lodžie', 'Terasa'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'loggia',
#       'terrace',
#       'brick',
#       'elevator',
#       'parking_lots',
#       'garage',
#       'partly_furnished'],
#      ['playground',
#       'small_shop',
#       'vet',
#       'theater',
#       'candy_shop',
#       'tavern',
#       'movies',
#       'post_office',
#       'metro',
#       'train',
#       'bus_public_transport',
#       'restaurant',
#       'atm',
#       'drugstore',
#       'sports',
#       'school',
#       'kindergarten',
#       'tram',
#       'shop']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-sobin-zeleticka'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2225656908',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2225656908',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Sobín',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2225656908,
#     'attractive_offer': 0,
#     'price': 9053000,
#     'price_czk': {'value_raw': 9053000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_q/PWaBfag.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_q/PWaBfag.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/13?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2225656908'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_q/PWaBfag.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gT_s/XeaBfiF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_q/bhsBfah.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_s/LFZBfP0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_q/xyjBfc6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_s/cSZBfP1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_q/PWaBfag.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 98\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.050939410894806, 'lon': 14.286252589105196},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'brick',
#       'cellar',
#       'parking_lots',
#       'partly_furnished'],
#      ['playground',
#       'small_shop',
#       'tavern',
#       'movies',
#       'vet',
#       'candy_shop',
#       'theater',
#       'bus_public_transport',
#       'kindergarten',
#       'post_office',
#       'sports',
#       'restaurant',
#       'drugstore',
#       'shop',
#       'atm',
#       'train',
#       'school',
#       'medic',
#       'tram']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 7,
#      'category_type_cb': 1,
#      'locality': 'praha-zbraslav-zitavskeho'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1252443212',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1252443212',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Zbraslav',
#     'has_video': False,
#     'advert_images_count': 5,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1252443212,
#     'attractive_offer': 0,
#     'price': 12296000,
#     'price_czk': {'value_raw': 12296000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jb/AtESfj.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jb/AtESfj.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/14?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1252443212'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jb/AtESfj.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LX/gUNBIpJ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LX/CxIBIpK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/oaIS2I.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gT_t/vSMDAw.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jb/AtESfj.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': True,
#     'name': 'Prodej bytu 3+1\xa0130\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 49.95618641089481, 'lon': 14.407669589105197},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['personal', 'panel', 'partly_furnished'],
#      ['playground',
#       'small_shop',
#       'vet',
#       'theater',
#       'candy_shop',
#       'tavern',
#       'movies',
#       'kindergarten',
#       'sports',
#       'atm',
#       'restaurant',
#       'train',
#       'drugstore',
#       'shop',
#       'school',
#       'tram',
#       'metro',
#       'bus_public_transport',
#       'post_office',
#       'medic']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 7,
#      'category_type_cb': 1,
#      'locality': 'praha-zlicin-nedasovska'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/389686860',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/389686860',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'RE-MAX-Partner-Praha-Reporyje',
#       'id': 17196,
#       'name': 'RE/MAX Partner',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_F/ccfIgx.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Zličín',
#     'has_video': False,
#     'advert_images_count': 11,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 389686860,
#     'attractive_offer': 0,
#     'price': 10460000,
#     'price_czk': {'value_raw': 10460000, 'unit': '', 'name': 'Celková cena'},
# ...
#      'self': {'href': '/cs/v2/estates/3787564620'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Ji/T5LGJK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kz/6fkGSS.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kz/v6XGSU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jc/GZSGJQ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_La/7dzGNf.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Ji/T5LGJK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 1+kk 17\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.0882554108948, 'lon': 14.441429589105196},
#     'has_matterport_url': False},
#    {'labelsReleased': [['terrace'], []],
#     'has_panorama': 0,
#     'labels': ['Terasa'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'balcony',
#       'terrace',
#       'brick',
#       'cellar',
#       'parking_lots',
#       'partly_furnished'],
#      ['playground',
#       'tavern',
#       'candy_shop',
#       'theater',
#       'movies',
#       'vet',
#       'small_shop',
#       'school',
#       'sports',
#       'post_office',
#       'train',
#       'kindergarten',
#       'drugstore',
#       'bus_public_transport',
#       'restaurant',
#       'medic',
#       'shop',
#       'atm']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-uhrineves-hulanova'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1316856908',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1316856908',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 10 - Uhříněves',
#     'has_video': True,
#     'advert_images_count': 30,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1316856908,
#     'attractive_offer': 0,
#     'price': 14906000,
#     'price_czk': {'value_raw': 14906000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jw/XLXzNl.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jw/XLXzNl.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/17?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1316856908'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jw/XLXzNl.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_q/Qgqtsq.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gQ_q/Leot4Y.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kq/MmmLah.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jg/48dziQ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_q/urAtsr.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jw/XLXzNl.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 131\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.016332410894805, 'lon': 14.621152589105197},
#     'has_matterport_url': True},
#    {'labelsReleased': [['loggia'], ['metro']],
#     'has_panorama': 0,
#     'labels': ['Lodžie', 'Metro 7 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'loggia',
#       'brick',
#       'cellar',
#       'elevator',
#       'partly_furnished'],
#      ['playground',
#       'small_shop',
#       'candy_shop',
#       'vet',
#       'tavern',
#       'theater',
#       'natural_attraction',
#       'movies',
#       'sightseeing',
#       'tram',
#       'kindergarten',
#       'bus_public_transport',
#       'train',
#       'medic',
#       'drugstore',
#       'atm',
#       'restaurant',
#       'post_office',
#       'metro',
#       'shop',
#       'school',
#       'sports']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-smichov-na-celne'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2504860748',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2504860748',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Smíchov',
#     'has_video': True,
#     'advert_images_count': 30,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2504860748,
#     'attractive_offer': 0,
#     'price': 20594000,
#     'price_czk': {'value_raw': 20594000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J0/ofDBuG.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J0/ofDBuG.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/18?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2504860748'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J0/ofDBuG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kz/z4tBvu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L8/q7cBvV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jh/AkrBtU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kz/uRHBvv.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kv/sIgBtu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J0/ofDBuG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 136\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.05777141089481, 'lon': 14.423112589105196},
#     'has_matterport_url': True},
#    {'labelsReleased': [['not_furnished'], ['medic']],
#     'has_panorama': 0,
#     'labels': ['Nevybavený', 'Lékař 7 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'brick',
#       'cellar',
#       'parking_lots',
#       'not_furnished'],
#      ['playground',
#       'small_shop',
#       'candy_shop',
#       'vet',
#       'tavern',
#       'theater',
#       'movies',
#       'natural_attraction',
#       'sightseeing',
#       'medic',
#       'post_office',
#       'tram',
#       'drugstore',
#       'school',
#       'sports',
#       'kindergarten',
#       'restaurant',
#       'atm',
#       'shop',
#       'bus_public_transport',
#       'train',
#       'metro']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-smichov-zubateho'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/163095628',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/163095628',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'HOME-4-PEOPLE-H4P-ProfiReal-Praha-Smichov',
#       'id': 27573,
#       'name': 'HOME 4 PEOPLE - H4P ProfiReal',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_M/TAlCCz.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Smíchov',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 163095628,
#     'attractive_offer': 0,
#     'price': 12708000,
#     'price_czk': {'value_raw': 12708000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_s/I7dBrwf.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_s/I7dBrwf.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/19?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/163095628'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_s/I7dBrwf.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_q/4DmBsIL.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KV/D0BY6F.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KV/73qY6G.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_q/YBpBr6D.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_q/yGKBr3Y.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_s/I7dBrwf.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 103\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.063184410894806, 'lon': 14.416851589105196},
#     'has_matterport_url': True},
#    {'labelsReleased': [['not_furnished'], ['medic']],
#     'has_panorama': 0,
#     'labels': ['Nevybavený', 'Lékař 7 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'brick',
#       'cellar',
#       'parking_lots',
#       'not_furnished'],
#      ['playground',
#       'small_shop',
#       'candy_shop',
#       'vet',
#       'tavern',
#       'theater',
#       'movies',
#       'natural_attraction',
#       'sightseeing',
#       'metro',
#       'medic',
#       'kindergarten',
#       'restaurant',
#       'tram',
#       'post_office',
#       'shop',
#       'drugstore',
#       'atm',
#       'school',
#       'sports',
#       'train',
#       'bus_public_transport']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-smichov-zubateho'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3484984396',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3484984396',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'HOME-4-PEOPLE-H4P-ProfiReal-Praha-Smichov',
#       'id': 27573,
#       'name': 'HOME 4 PEOPLE - H4P ProfiReal',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_M/TAlCCz.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Smíchov',
#     'has_video': False,
#     'advert_images_count': 19,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3484984396,
#     'attractive_offer': 0,
#     'price': 13257000,
#     'price_czk': {'value_raw': 13257000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jb/M4NBtY1.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jb/M4NBtY1.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/20?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3484984396'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jb/M4NBtY1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/7lcW1m.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_s/uznn9z.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_r/DuRBr5Z.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jy/12qiOL.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ks/aIscXs.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jb/M4NBtY1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 101\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.063184410894806, 'lon': 14.416851589105196},
#     'has_matterport_url': True}],
#   'is_saved': {'email_notification': False,
#    'notification_advert_count': 0,
#    'stack_id': 0,
#    'push_notification': False,
#    '_links': {'self': {'href': '/cs/v2/stacks'}},
#    'removed': False,
#    'saved': False},
#   'not_precise_location_count': {'result_size_auction': 0,
#    'result_size': 1552,
#    '_links': {'self': {'profile': '/estates/count/doc',
#      'href': '/cs/v2/estates/count?category_main_cb=1&locality_region_id=10&category_type_cb=3',
#      'title': 'Estate count'}}}},
#  'filterLabels': [],
#  'title': 'Byty na prodej Praha',
#  'filter': {'category_main_cb': '1',
#   'suggested_districtId': -1,
#   'locality_region_id': '10',
#   'category_type_cb': '1',
#   'suggested_regionId': -1},
#  '_links': {'self': {'href': '/cs/v2/estates?category_main_cb=1&locality_region_id=10&category_type_cb=1&page=1'},
#   'clusters_with_bounding_box_of_first_10': {'href': '/cs/v2/clusters?category_main_cb=1&locality_region_id=10&category_type_cb=1&per_page60=&leftBottomBounding=14.3631355891|50.0119574109&page=1&rightTopBounding=14.5904465891|50.1286984109'},
#   'rss': {'href': '/api/cs/v2/estates/rss?category_main_cb=1&category_type_cb=1&locality_region_id=10&suggested_regionId=-1&suggested_districtId=-1'}},
#  'locality': 'okres Praha 3',
#  'locality_dativ': 'na Praze 3',
#  'logged_in': False,
#  'per_page': 20,
#  'category_instrumental': 'výběrem či prodejem bytu',
#  'page': 1,
#  'filterLabels2': {'something_more3_3310': 'elevator',
#   'something_more1_3120': 'cellar',
#   'something_more1_3100': 'loggia',
#   'furnished_1': 'furnished',
#   'furnished_2': 'partly_furnished',
#   'furnished_3': 'not_furnished',
#   'building_condition_9': 'after_reconstruction',
#   'something_more2_3150': 'garage',
#   'something_more2_3130': 'basin',
#   'ownership_1': 'personal',
#   'ownership_3': 'state',
#   'ownership_2': 'collective',
#   'something_more3_1820': 'easy_access',
#   'energy_efficiency_rating_search_7': 'energy_rating_g',
#   'energy_efficiency_rating_search_6': 'energy_rating_f',
#   'energy_efficiency_rating_search_5': 'energy_rating_e',
#   'energy_efficiency_rating_search_4': 'energy_rating_d',
#   'energy_efficiency_rating_search_3': 'energy_rating_c',
#   'energy_efficiency_rating_search_2': 'energy_rating_b',
#   'energy_efficiency_rating_search_1': 'energy_rating_a',
#   'something_more1_3110': 'terrace',
#   'building_condition_6': 'new_building',
#   'something_more1_3090': 'balcony',
#   'building_condition_4': 'in_construction',
#   'building_type_search_3': 'other_sigular',
#   'something_more2_3120': 'cellar',
#   'building_type_search_1': 'panel',
#   'something_more2_3140': 'parking_lots',
#   'something_more1_200222': 'garden',
#   'building_type_search_2': 'brick'}}

# %% [markdown]
# ### 1c. Combining multiple requests into single df
#
# * Function should parametrize:
#     * `start_page` and `end_page`
#     * request parameters
# * construct a list of individual request dfs
# * then feed it into `pd.concat` function

# %%
start_page = int(input("start page input: "))
end_page = int(input("end page input: "))

# %%
def single_df(start_page, end_page, category_main_cb, category_type_cb, locality_region_id):
    l = [sreality_to_pd(getting_sreality(category_main_cb, category_type_cb, locality_region_id, i)) for i in range(start_page, end_page + 1)]
    return pd.concat([pd.json_normalize(df["_embedded"]["estates"], max_level = 0) for df in l]).reset_index(drop = True)

# %% [markdown]
# ## Task 2: Cleaning data
#
# ### 2a. Filter columns
# * filter only columns: `['locality', 'price', 'name', 'gps','hash_id','labelsAll','exclusively_at_rk']`
# * use `.copy()` to avoid `SettingWithCopyWarning` later

# %%
df = single_df(start_page, end_page, category_main_cb, category_type_cb, locality_region_id)[['locality', 'price', 'name', 'gps','hash_id','labelsAll','exclusively_at_rk']].copy(deep = True)

# %% [markdown]
# ### 2b: GPS
# * Convert dictionary in `gps` column into two columns - `lat` and `lon`
# * use apply function on gps column
# * Note apply can return multiple columns

# %%
df = pd.concat([df, df["gps"].apply(pd.Series)], axis = 1).copy(deep = True)

# %% [markdown]
# ### 2b. Get flat type from name
# * Name is always represented by string `Prodej bytu [type of flat] [Area] m^2`
# * try picking third word in string
# * check meaningfulness using `.value_counts()`

# %%
df["type_of_flat"] = df["name"].apply(lambda v: v.split()[2])

# %% [markdown]
# ### 2c. Get area from name
# * Naive: select the word before last word
# * Then try navigating using the index of `'m²'`
# * if this also fail, then you will need to use regex

# %%
df["area"] = df["name"].apply(lambda v: int(v.split()[3]))

# %% [markdown]
# ## Task 3 (Homework): Convert column`labelsAll` into boolean variables
#
# ### Task 3a. Get all possible label names
# * deal with nested-list structure
# * Hint: try sum the whole column to get a nested list of lists.
# * Then flatten the nested list (2D to 1D)
# * Finally keep only unique elements

# %%
df["labelsAll"] = df["labelsAll"].apply(lambda x: [item for sublist in x for item in sublist])

# %%
pd.Series([item for sublist in [i for i in df["labelsAll"]] for item in sublist]).unique()
# Out:
# array(['new_building', 'personal', 'loggia', 'terrace', 'cellar',
#        'elevator', 'not_furnished', 'playground', 'tavern', 'small_shop',
#        'movies', 'theater', 'candy_shop', 'vet', 'natural_attraction',
#        'kindergarten', 'tram', 'sports', 'school', 'bus_public_transport',
#        'metro', 'restaurant', 'drugstore', 'medic', 'atm', 'post_office',
#        'train', 'shop', 'after_reconstruction', 'brick', 'sightseeing',
#        'balcony', 'parking_lots', 'garage', 'partly_furnished', 'panel',
#        'collective', 'furnished', 'in_construction'], dtype=object)

# %% [markdown]
# ### 4b. Test existence of label `cellar` for offers
# * again deal with nested list of list structure
# * write generic function `test_existence_of_label(offer_labels,label)`

# %%
df.head(50)
# Out:
#                    locality     price                               name  \
# 0       Praha 5 - Hlubočepy  13642000             Prodej bytu 3+kk 88 m²
# 1          Praha 3 - Žižkov  15504000        Prodej bytu atypické 146 m²
# 2       Praha 4 - Záběhlice   4809000              Prodej bytu 2+1 57 m²
# 3        Praha 9 - Vysočany   6195000             Prodej bytu 1+kk 36 m²
# 4        Praha 9 - Vysočany  16538000             Prodej bytu 4+1 181 m²
# 5      Praha 6 - Veleslavín   5352000             Prodej bytu 2+kk 46 m²
# 6            Praha 9 - Kyje  10332000             Prodej bytu 4+kk 91 m²
# 7           Praha 8 - Troja   9257000             Prodej bytu 2+kk 79 m²
# 8          Praha 3 - Žižkov   5688000             Prodej bytu 2+kk 48 m²
# 9      Praha 2 - Nové Město   5781000              Prodej bytu 1+1 36 m²
# 10     Praha 10 - Uhříněves   5584000             Prodej bytu 2+kk 46 m²
# 11            Praha 4 - Krč   9412000              Prodej bytu 3+1 78 m²
# 12          Praha 5 - Sobín   6816000             Prodej bytu 2+kk 74 m²
# 13         Praha 3 - Žižkov   3826000             Prodej bytu 1+kk 24 m²
# 14          Praha 6 - Liboc   9143000              Prodej bytu 3+1 78 m²
# 15         Praha 8 - Karlín         0   Prodej bytu 3+1 127 m² (Mezonet)
# 16         Praha 8 - Karlín         0  Prodej bytu 5+kk 160 m² (Mezonet)
# 17          Praha 8 - Libeň  13441000  Prodej bytu 3+kk 100 m² (Mezonet)
# 18      Praha 10 - Vršovice   5368000             Prodej bytu 2+kk 65 m²
# 19       Praha 9 - Střížkov   5683000             Prodej bytu 2+kk 56 m²
# 20           Praha 6 - Řepy   5170000             Prodej bytu 1+kk 44 m²
# 21      Praha 5 - Hlubočepy   9433000             Prodej bytu 3+kk 67 m²
# 22     Praha 7 - Holešovice   5688000              Prodej bytu 1+1 41 m²
# 23     Praha 10 - Strašnice   5016000             Prodej bytu 1+kk 36 m²
# 24           Praha 6 - Řepy   5480000             Prodej bytu 1+kk 44 m²
# 25           Praha 6 - Řepy   6204000             Prodej bytu 2+kk 45 m²
# 26         Praha 10 - Dubeč  11263000             Prodej bytu 3+kk 88 m²
# 27     Praha 10 - Petrovice   6722000              Prodej bytu 3+1 73 m²
# 28  Praha 5 - Velká Chuchle   9205000             Prodej bytu 3+kk 85 m²
# 29      Praha 10 - Hostivař   4126000             Prodej bytu 1+kk 55 m²
# 30     Praha 10 - Strašnice  11891000    Prodej bytu 3+1 92 m² (Mezonet)
# 31      Praha 9 - Hloubětín   7239000             Prodej bytu 2+kk 61 m²
# 32        Praha 5 - Smíchov         0             Prodej bytu 2+kk 48 m²
# 33        Praha 5 - Smíchov         0             Prodej bytu 3+1 100 m²
# 34        Praha 5 - Smíchov         0              Prodej bytu 2+1 66 m²
# 35        Praha 5 - Smíchov         0             Prodej bytu 2+kk 48 m²
# 36                  Praha 5   8953000             Prodej bytu 2+kk 47 m²
# 37                  Praha 5   6231000             Prodej bytu 1+kk 29 m²
# 38         Praha 4 - Braník   5430000              Prodej bytu 2+1 61 m²
# 39       Praha 5 - Stodůlky   6826000              Prodej bytu 3+1 84 m²
# 40      Praha 10 - Malešice   8264000              Prodej bytu 3+1 74 m²
# 41        Praha 7 - Bubeneč   5169000             Prodej bytu 2+kk 28 m²
# 42      Praha 5 - Hlubočepy  13435000             Prodej bytu 3+kk 87 m²
# 43         Praha 5 - Košíře   8687000             Prodej bytu 3+kk 87 m²
# 44        Praha 6 - Břevnov   5119000              Prodej bytu 2+1 53 m²
# 45         Praha 3 - Žižkov   4646000              Prodej bytu 1+1 23 m²
# 46     Praha 10 - Petrovice   6723000              Prodej bytu 3+1 73 m²
# 47            Praha 4 - Krč   7378000              Prodej bytu 2+1 71 m²
# 48          Praha 4 - Kamýk   8264000              Prodej bytu 3+1 80 m²
# 49       Praha 9 - Vysočany   4757000              Prodej bytu 1+1 54 m²
#
#                                                   gps     hash_id  \
# 0   {'lat': 50.02206976811756, 'lon': 14.389917231...   834861916
# 1   {'lat': 50.07649476811756, 'lon': 14.459372231...  3750241356
# 2   {'lat': 50.03731776811756, 'lon': 14.504512231...  1759475532
# 3   {'lat': 50.10492576811756, 'lon': 14.508641231...  1321411660
# 4   {'lat': 50.093629768117566, 'lon': 14.51848423...  2930648140
# 5   {'lat': 50.08246076811756, 'lon': 14.341159231...   464053324
# 6   {'lat': 50.104856768117564, 'lon': 14.57564323...  2118333516
# 7   {'lat': 50.109792768117565, 'lon': 14.45155123...  2879833164
# 8   {'lat': 50.08008376811756, 'lon': 14.494732231...  2361599052
# 9   {'lat': 50.06598076811756, 'lon': 14.438227231...  3266631500
# 10  {'lat': 50.01883576811756, 'lon': 14.604030231...  1774306380
# 11  {'lat': 50.03601676811756, 'lon': 14.456882231...  1920616268
# 12  {'lat': 50.05433476811756, 'lon': 14.282857231...  2225656908
# 13  {'lat': 50.07605976811756, 'lon': 14.456294231...  2184430668
# 14  {'lat': 50.07877176811756, 'lon': 14.336894231...  1203971148
# 15  {'lat': 50.07925676811756, 'lon': 14.455713231...  4066219852
# 16  {'lat': 50.07925676811756, 'lon': 14.455713231...   576558924
# 17  {'lat': 50.092706768117566, 'lon': 14.48987323...  4138345548
# 18  {'lat': 50.059236768117565, 'lon': 14.48051323...  3648616540
# 19  {'lat': 50.12014576811756, 'lon': 14.505423231...  1722926156
# 20  {'lat': 50.05832876811756, 'lon': 14.323324231...  3941803084
# 21  {'lat': 50.02176076811756, 'lon': 14.390232231...  1386535516
# 22  {'lat': 50.09547276811756, 'lon': 14.459895231...  3693646924
# 23  {'lat': 50.068059768117564, 'lon': 14.49768723...   567731276
# 24  {'lat': 50.05832876811756, 'lon': 14.323324231...   200483916
# 25  {'lat': 50.05832876811756, 'lon': 14.323324231...  1542661196
# 26  {'lat': 50.052228768117565, 'lon': 14.60349823...  2884838476
# 27  {'lat': 50.022211768117565, 'lon': 14.57262723...  1586947148
# 28  {'lat': 49.997003768117565, 'lon': 14.39376223...  1758057548
# 29  {'lat': 50.04185676811756, 'lon': 14.543264231...  1689757516
# 30  {'lat': 50.06557276811756, 'lon': 14.511671231...  1932490572
# 31  {'lat': 50.09018176811756, 'lon': 14.537606231...   616641612
# 32  {'lat': 50.05429676811756, 'lon': 14.420453231...  3270218828
# 33  {'lat': 50.05429676811756, 'lon': 14.420453231...  2917897292
# 34  {'lat': 50.05429676811756, 'lon': 14.420453231...  3706426444
# 35  {'lat': 50.05429676811756, 'lon': 14.420453231...   216765516
# 36  {'lat': 50.044931768117564, 'lon': 14.41939423...  1530213964
# 37  {'lat': 50.044931768117564, 'lon': 14.41939423...  4068947532
# 38  {'lat': 50.016805768117564, 'lon': 14.43088923...  3833787468
# 39  {'lat': 50.025816768117565, 'lon': 14.35127323...  4277347404
# 40  {'lat': 50.07384676811756, 'lon': 14.524225231...  4037748300
# 41  {'lat': 50.090745768117564, 'lon': 14.43426923...  3236439116
# 42  {'lat': 50.02206976811756, 'lon': 14.389917231...   648215388
# 43  {'lat': 50.05763476811756, 'lon': 14.375856231...  3900426060
# 44  {'lat': 50.07574676811756, 'lon': 14.358183231...  2875053132
# 45  {'lat': 50.079412768117564, 'lon': 14.48033823...  2060710988
# 46  {'lat': 50.022211768117565, 'lon': 14.57262723...  1635899212
# 47  {'lat': 50.03301076811756, 'lon': 14.461916231...  2301744204
# 48  {'lat': 50.00864276811756, 'lon': 14.455794231...   439113548
# 49  {'lat': 50.100313768117566, 'lon': 14.52814923...  3517367372
#
#                                             labelsAll  exclusively_at_rk  \
# 0   [new_building, personal, loggia, terrace, cell...                  1
# 1   [personal, after_reconstruction, terrace, bric...                  1
# 2   [personal, balcony, brick, elevator, parking_l...                  1
# 3   [new_building, personal, terrace, cellar, elev...                  0
# 4   [new_building, personal, balcony, terrace, bri...                  0
# 5   [personal, brick, cellar, not_furnished, playg...                  1
# 6   [new_building, personal, balcony, brick, eleva...                  1
# 7   [personal, terrace, cellar, elevator, garage, ...                  1
# 8   [personal, loggia, panel, cellar, elevator, ca...                  0
# 9   [personal, brick, playground, small_shop, vet,...                  0
# 10  [new_building, personal, brick, elevator, not_...                  1
# 11  [personal, brick, cellar, elevator, not_furnis...                  0
# 12  [new_building, personal, balcony, loggia, terr...                  0
# 13  [personal, brick, elevator, playground, vet, s...                  0
# 14  [collective, balcony, panel, cellar, elevator,...                  0
# 15  [in_construction, personal, terrace, brick, ce...                  0
# 16  [in_construction, personal, terrace, brick, ce...                  0
# 17  [new_building, personal, terrace, brick, eleva...                  0
# 18  [personal, brick, cellar, elevator, parking_lo...                  1
# 19  [new_building, personal, loggia, brick, elevat...                  1
# 20  [new_building, personal, balcony, brick, cella...                  0
# 21  [new_building, personal, elevator, not_furnish...                  1
# 22  [collective, elevator, not_furnished, playgrou...                  1
# 23  [personal, elevator, furnished, playground, na...                  1
# 24  [new_building, personal, balcony, brick, cella...                  0
# 25  [new_building, personal, brick, cellar, elevat...                  0
# 26  [personal, balcony, brick, elevator, parking_l...                  0
# 27  [personal, loggia, panel, cellar, elevator, pl...                  0
# 28  [new_building, personal, terrace, brick, garag...                  1
# 29  [personal, balcony, brick, cellar, garage, pla...                  0
# 30  [personal, loggia, partly_furnished, tavern, c...                  1
# 31  [new_building, personal, balcony, cellar, elev...                  1
# 32  [personal, after_reconstruction, brick, elevat...                  0
# 33  [personal, after_reconstruction, balcony, bric...                  0
# 34  [personal, after_reconstruction, brick, elevat...                  0
# 35  [personal, after_reconstruction, balcony, bric...                  0
# 36  [in_construction, personal, balcony, elevator,...                  1
# 37  [in_construction, personal, loggia, elevator, ...                  1
# 38  [personal, loggia, panel, cellar, playground, ...                  0
# 39  [personal, loggia, panel, cellar, partly_furni...                  0
# 40  [personal, loggia, panel, cellar, elevator, sm...                  0
# 41  [personal, after_reconstruction, brick, elevat...                  1
# 42  [new_building, personal, loggia, terrace, cell...                  1
# 43  [personal, balcony, brick, cellar, theater, ca...                  0
# 44  [collective, panel, not_furnished, playground,...                  1
# 45  [personal, brick, elevator, candy_shop, small_...                  0
# 46  [personal, loggia, panel, cellar, elevator, pa...                  0
# 47  [personal, brick, cellar, elevator, playground...                  0
# 48  [personal, panel, elevator, small_shop, tavern...                  0
# 49  [collective, balcony, brick, cellar, partly_fu...                  1
#
#           lat        lon type_of_flat  area
# 0   50.022070  14.389917         3+kk    88
# 1   50.076495  14.459372     atypické   146
# 2   50.037318  14.504512          2+1    57
# 3   50.104926  14.508641         1+kk    36
# 4   50.093630  14.518484          4+1   181
# 5   50.082461  14.341159         2+kk    46
# 6   50.104857  14.575643         4+kk    91
# 7   50.109793  14.451551         2+kk    79
# 8   50.080084  14.494732         2+kk    48
# 9   50.065981  14.438227          1+1    36
# 10  50.018836  14.604030         2+kk    46
# 11  50.036017  14.456882          3+1    78
# 12  50.054335  14.282857         2+kk    74
# 13  50.076060  14.456294         1+kk    24
# 14  50.078772  14.336894          3+1    78
# 15  50.079257  14.455713          3+1   127
# 16  50.079257  14.455713         5+kk   160
# 17  50.092707  14.489873         3+kk   100
# 18  50.059237  14.480513         2+kk    65
# 19  50.120146  14.505423         2+kk    56
# 20  50.058329  14.323324         1+kk    44
# 21  50.021761  14.390232         3+kk    67
# 22  50.095473  14.459895          1+1    41
# 23  50.068060  14.497687         1+kk    36
# 24  50.058329  14.323324         1+kk    44
# 25  50.058329  14.323324         2+kk    45
# 26  50.052229  14.603498         3+kk    88
# 27  50.022212  14.572627          3+1    73
# 28  49.997004  14.393762         3+kk    85
# 29  50.041857  14.543264         1+kk    55
# 30  50.065573  14.511671          3+1    92
# 31  50.090182  14.537606         2+kk    61
# 32  50.054297  14.420453         2+kk    48
# 33  50.054297  14.420453          3+1   100
# 34  50.054297  14.420453          2+1    66
# 35  50.054297  14.420453         2+kk    48
# 36  50.044932  14.419394         2+kk    47
# 37  50.044932  14.419394         1+kk    29
# 38  50.016806  14.430889          2+1    61
# 39  50.025817  14.351273          3+1    84
# 40  50.073847  14.524225          3+1    74
# 41  50.090746  14.434269         2+kk    28
# 42  50.022070  14.389917         3+kk    87
# 43  50.057635  14.375856         3+kk    87
# 44  50.075747  14.358183          2+1    53
# 45  50.079413  14.480338          1+1    23
# 46  50.022212  14.572627          3+1    73
# 47  50.033011  14.461916          2+1    71
# 48  50.008643  14.455794          3+1    80
# 49  50.100314  14.528149          1+1    54

# %% [markdown]
# ### 4c. Test existence of all possible labels
# * use apply returning series with all labels
